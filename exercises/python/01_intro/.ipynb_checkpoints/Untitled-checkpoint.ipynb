# %%
def is_palindrome(string_var):     
    '''
    returns True if string_var is palindrome, False otherwise
    '''
    ret = None
    string_var = string_var.lower()
    rev = string_var[::-1]
    ret = (rev == string_var)
    return ret 

def histogram_letters(string_var):     
    '''
    count how many times a letter is present in the string_var
    and returns a dict

    '''
    ret = {}
    string_var = string_var.lower()
    l = list(string_var)
    print(l)
    for i in l:
        if i not in ret:
            ret[i] = 1
            continue
        ret[i] += 1
    return ret 

def get_most_frequent(list_var):
    '''
    returns a tuple with the most frequent object in the list with the 
    corresponing number
    '''
    ret = None
    dictionary = {}
    for i in list_var:
        if i not in dictionary:
            dictionary[i] = 1
            continue
        dictionary[i] += 1
    
    ret = (0,0)
    for k,v in dictionary.items():
        if v > ret[1]:
            ret = (k,v)
    return ret

def which_duplicates(list_var):
    '''
    return a dict with containing the repeted object and the number of repetitions
    '''
    ret = None
    ########################
    # code here
    ########################
    return ret


def compute_factorial(int_val):
    '''
    returns factorial of a number
    '''
    ret = None
    if int_val == 1:
        return 1
    ret = int_val * compute_factorial(int_val-1)
    return ret


def is_prime(int_val):
    '''
    returns True if int_val is prime, False otherwise
    '''
    ret = None
    ########################
    # code here
    ########################
    return ret

# %%
print(is_palindrome("Bob"))
print(is_palindrome("Marty"))
print(histogram_letters("Adda"))
print(histogram_letters("Marty"))
print(get_most_frequent("Adda"))
print(get_most_frequent("Supercalifragilistichespiralidoso"))
print(compute_factorial(5))
# Out:
# True
# False
# ['a', 'd', 'd', 'a']
# {'a': 2, 'd': 2}
# ['m', 'a', 'r', 't', 'y']
# {'m': 1, 'a': 1, 'r': 1, 't': 1, 'y': 1}
# ('d', 2)
# ('i', 6)
# 120
